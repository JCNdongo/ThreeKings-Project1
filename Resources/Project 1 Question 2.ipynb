# %%
import os 
import csv
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import smtplib
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
#Load the dataset
file = os.path.join('Desktop', 'GitHub', 'ThreeKings-Project1', 'Resources', 'wage_predict.csv')
data = pd.read_csv(file)

# %%
data.head()
# Out:
#   industry  occupation  yrs_qual  sex  highest_qual  area_of_study  \
# 0        Q           2        19    1            13              4
# 1        C           9        14    1            11              7
# 2        L           3        16    2            12              4
# 3        Q           5        12    2             7              4
# 4        P           1        18    1            13              4
#
#    influencing  negotiating  sector  workforce_change  ...  advising  \
# 0            2            1       1                 3  ...         5
# 1            4            2       1                 1  ...         5
# 2            2            1       1                 3  ...         3
# 3            5            4       2                 1  ...         5
# 4            3            4       3                 3  ...         4
#
#    instructing  problem_solving_quick  problem_solving_long  labour  \
# 0            4                      5                     4       4
# ...

# %%
# Regression analysis of influencing on salary
X = sm.add_constant(data['influencing'])
model = sm.OLS(data['monthly_salary'], X)
results = model.fit() 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         monthly_salary   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     42.32
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):           9.75e-11
# Time:                        21:51:40   Log-Likelihood:                -19768.
# No. Observations:                2005   AIC:                         3.954e+04
# Df Residuals:                    2003   BIC:                         3.955e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3067.0649    228.700     13.411      0.000    2618.550    3515.580
# ...

# %%
# Scatter plot with regression line
plt.scatter(data['influencing'], data['monthly_salary'])
plt.plot(data['influencing'], results.predict(), color='red')
plt.xlabel('influencing')
plt.ylabel('Salary')
plt.title('Influencing vs. Salary')
plt.show()
